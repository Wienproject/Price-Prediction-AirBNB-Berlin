# %% [markdown]
# # FEATURE SELECTION

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sidetable as stb
import joblib
from yellowbrick.datasets import load_concrete
from yellowbrick.regressor import ResidualsPlot

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

from sklearn import set_config
set_config(print_changed_only=False)

from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %%
df =pd.read_csv('listings2.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2015  https://www.airbnb.com/rooms/2015  20201013162227   2020-10-21
# 1  3176  https://www.airbnb.com/rooms/3176  20201013162227   2020-10-20
# 2  3309  https://www.airbnb.com/rooms/3309  20201013162227   2020-10-21
# 3  7071  https://www.airbnb.com/rooms/7071  20201013162227   2020-10-19
# 4  9991  https://www.airbnb.com/rooms/9991  20201013162227   2020-10-20
#
#                                                name  \
# 0  Berlin-Mitte Value! Quiet courtyard/very central
# 1                   Fabulous Flat in great Location
# 2                 BerlinSpot Schöneberg near KaDeWe
# 3                  BrightRoom with sunny greenview!
# 4               Geourgeous flat - outstanding views
#
#                                          description  \
# 0  Great location!  <br />30 of 75 sq meters. Thi...
# 1  This beautiful first floor apartment  is situa...
# 2  First of all:<br />I prefer short-notice booki...
# 3  Cozy and large room in the beautiful district ...
# 4  4 bedroom with very large windows and outstand...
#
#                                neighborhood_overview  \
# 0  It is located in the former East Berlin area o...
# 1  The neighbourhood is famous for its variety of...
# 2  My flat is in the middle of West-Berlin, direc...
# 3  Great neighborhood with plenty of Cafés, Baker...
# 4  Prenzlauer Berg is an amazing neighbourhood wh...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/260fd609-710a...     2217
# 1  https://a0.muscache.com/pictures/243355/84afcf...     3718
# 2  https://a0.muscache.com/pictures/29054294/b1fa...     4108
# 3  https://a0.muscache.com/pictures/21278/32a1622...    17391
# 4  https://a0.muscache.com/pictures/42799131/59c8...    33852
#
#                                   host_url   host_name  host_since  \
# 0   https://www.airbnb.com/users/show/2217         Ion  2008-08-18
# 1   https://www.airbnb.com/users/show/3718      Britta  2008-10-19
# 2   https://www.airbnb.com/users/show/4108        Jana  2008-11-07
# 3  https://www.airbnb.com/users/show/17391  BrightRoom  2009-05-16
# 4  https://www.airbnb.com/users/show/33852     Philipp  2009-08-25
#
#                           host_location  \
# 0  Key Biscayne, Florida, United States
# 1  Coledale, New South Wales, Australia
# 2               Berlin, Berlin, Germany
# 3               Berlin, Berlin, Germany
# 4               Berlin, Berlin, Germany
#
#                                           host_about host_response_time  \
# 0                       Isn’t sharing economy great?     within an hour
# 1  We love to travel ourselves a lot and prefer t...                NaN
# 2  ENJOY EVERY DAY AS IF IT'S YOUR LAST!!! \r\n\r...       within a day
# 3  I am easy going and love making new friends! I...                NaN
# 4  Born in Munich - lives in and loves Berlin. Wo...                NaN
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  97%                 f
# 1                NaN                  67%                 f
# 2               100%                  NaN                 f
# 3                NaN                  97%                 t
# 4                NaN                  33%                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/21428...
# 1  https://a0.muscache.com/im/users/3718/profile_...
# 2  https://a0.muscache.com/im/pictures/user/d8049...
# 3  https://a0.muscache.com/im/pictures/user/48c3d...
# 4  https://a0.muscache.com/im/users/33852/profile...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/21428...              Mitte
# 1  https://a0.muscache.com/im/users/3718/profile_...    Prenzlauer Berg
# 2  https://a0.muscache.com/im/pictures/user/d8049...         Schöneberg
# 3  https://a0.muscache.com/im/pictures/user/48c3d...    Prenzlauer Berg
# 4  https://a0.muscache.com/im/users/33852/profile...    Prenzlauer Berg
#
#    host_listings_count  host_total_listings_count  \
# 0                  7.0                        7.0
# 1                  1.0                        1.0
# 2                  1.0                        1.0
# 3                  2.0                        2.0
# 4                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1  ['email', 'phone', 'facebook', 'reviews', 'man...                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
#
#   host_identity_verified    neighbourhood   neighbourhood_cleansed  \
# 0                      t  Berlin, Germany          Brunnenstr. Süd
# 1                      t  Berlin, Germany  Prenzlauer Berg Südwest
# 2                      f  Berlin, Germany          Schöneberg-Nord
# 3                      t  Berlin, Germany           Helmholtzplatz
# 4                      t  Berlin, Germany  Prenzlauer Berg Südwest
#
#   neighbourhood_group_cleansed  latitude  longitude  \
# 0                        Mitte  52.53454   13.40256
# 1                       Pankow  52.53500   13.41758
# 2       Tempelhof - Schöneberg  52.49885   13.34906
# 3                       Pankow  52.54316   13.41509
# 4                       Pankow  52.53303   13.41605
#
#                property_type        room_type  accommodates  bathrooms  \
# 0          Entire guesthouse  Entire home/apt             3        NaN
# 1           Entire apartment  Entire home/apt             4        NaN
# 2  Private room in apartment     Private room             1        NaN
# 3  Private room in apartment     Private room             2        NaN
# 4           Entire apartment  Entire home/apt             7        NaN
#
#   bathrooms_text  bedrooms  beds  \
# 0         1 bath       1.0   0.0
# 1         1 bath       1.0   2.0
# 2  1 shared bath       1.0   1.0
# 3  1 shared bath       1.0   2.0
# 4      2.5 baths       4.0   7.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Long term stays allowed", "Essentials", "Gar...   $61.14               5
# 1  ["Wifi", "Iron", "Smoke alarm", "Hangers", "Ki...   $90.00              62
# 2  ["Wifi", "Iron", "Smoke alarm", "Hangers", "Ca...   $28.57               7
# 3  ["Wifi", "Hangers", "Refrigerator", "Extra pil...   $33.00               1
# 4  ["Babysitter recommendations", "Room-darkening...  $180.00               6
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0            1125                     5.0                    29.0
# 1            1125                    62.0                    62.0
# 2              35                     7.0                     7.0
# 3              10                     1.0                     1.0
# 4              14                     6.0                     6.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                  1125.0                  1125.0                     8.5
# 1                  1125.0                  1125.0                    62.0
# 2                    35.0                    35.0                     7.0
# 3                    10.0                    10.0                     1.0
# 4                    14.0                    14.0                     6.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                  1125.0               NaN                t               30
# 1                  1125.0               NaN                t               18
# 2                    35.0               NaN                t                0
# 3                    10.0               NaN                t                0
# 4                    14.0               NaN                t                0
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               60               90               180            2020-10-21
# 1               48               78               353            2020-10-20
# 2                0               18               293            2020-10-21
# 3                0                0                 0            2020-10-19
# 4                0                0                29            2020-10-20
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                134                      4                       1
# 1                146                      1                       0
# 2                 27                      0                       0
# 3                293                     32                       0
# 4                  8                      1                       0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2016-04-11  2020-09-26                  93.0                    10.0
# 1   2009-06-20  2020-05-27                  93.0                     9.0
# 2   2013-08-12  2019-05-31                  89.0                     9.0
# 3   2009-08-18  2020-03-31                  97.0                    10.0
# 4   2015-08-09  2020-01-04                 100.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        9.0                   10.0
# 1                        9.0                    9.0
# 2                        9.0                    9.0
# 3                       10.0                   10.0
# 4                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                  9.0
# 1                          9.0                    10.0                  9.0
# 2                         10.0                     9.0                  9.0
# 3                         10.0                    10.0                  9.0
# 4                         10.0                    10.0                 10.0
#
#              license instant_bookable  calculated_host_listings_count  \
# 0                NaN                f                               6
# 1                NaN                f                               1
# 2                NaN                f                               1
# 3                NaN                t                               1
# 4  03/Z/RA/003410-18                f                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            6
# 1                                            1
# 2                                            0
# 3                                            0
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             1
# 3                                             1
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               2.43
# 1                                            0               1.06
# 2                                            0               0.31
# 3                                            0               2.15
# 4                                            0               0.13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20227 entries, 0 to 20226
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            20227 non-null  int64
#  1   listing_url                                   20227 non-null  object
#  2   scrape_id                                     20227 non-null  int64
#  3   last_scraped                                  20227 non-null  object
#  4   name                                          20195 non-null  object
#  5   description                                   19709 non-null  object
#  6   neighborhood_overview                         11054 non-null  object
#  7   picture_url                                   20227 non-null  object
#  8   host_id                                       20227 non-null  int64
#  9   host_url                                      20227 non-null  object
#  10  host_name                                     20215 non-null  object
#  11  host_since                                    20215 non-null  object
#  12  host_location                                 20167 non-null  object
#  13  host_about                                    10156 non-null  object
#  14  host_response_time                            10054 non-null  object
#  15  host_response_rate                            10054 non-null  object
#  16  host_acceptance_rate                          13053 non-null  object
#  17  host_is_superhost                             20215 non-null  object
#  18  host_thumbnail_url                            20215 non-null  object
#  19  host_picture_url                              20215 non-null  object
#  20  host_neighbourhood                            14547 non-null  object
#  21  host_listings_count                           20215 non-null  float64
#  22  host_total_listings_count                     20215 non-null  float64
#  23  host_verifications                            20227 non-null  object
#  24  host_has_profile_pic                          20215 non-null  object
#  25  host_identity_verified                        20215 non-null  object
#  26  neighbourhood                                 11055 non-null  object
#  27  neighbourhood_cleansed                        20227 non-null  object
#  28  neighbourhood_group_cleansed                  20227 non-null  object
#  29  latitude                                      20227 non-null  float64
#  30  longitude                                     20227 non-null  float64
#  31  property_type                                 20227 non-null  object
#  32  room_type                                     20227 non-null  object
#  33  accommodates                                  20227 non-null  int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                20205 non-null  object
#  36  bedrooms                                      18542 non-null  float64
#  37  beds                                          19975 non-null  float64
#  38  amenities                                     20227 non-null  object
#  39  price                                         20227 non-null  object
#  40  minimum_nights                                20227 non-null  int64
#  41  maximum_nights                                20227 non-null  int64
#  42  minimum_minimum_nights                        20224 non-null  float64
#  43  maximum_minimum_nights                        20224 non-null  float64
#  44  minimum_maximum_nights                        20224 non-null  float64
#  45  maximum_maximum_nights                        20224 non-null  float64
#  46  minimum_nights_avg_ntm                        20224 non-null  float64
#  47  maximum_nights_avg_ntm                        20224 non-null  float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              20227 non-null  object
#  50  availability_30                               20227 non-null  int64
#  51  availability_60                               20227 non-null  int64
#  52  availability_90                               20227 non-null  int64
#  53  availability_365                              20227 non-null  int64
#  54  calendar_last_scraped                         20227 non-null  object
#  55  number_of_reviews                             20227 non-null  int64
#  56  number_of_reviews_ltm                         20227 non-null  int64
#  57  number_of_reviews_l30d                        20227 non-null  int64
#  58  first_review                                  16460 non-null  object
#  59  last_review                                   16460 non-null  object
#  60  review_scores_rating                          16053 non-null  float64
#  61  review_scores_accuracy                        16034 non-null  float64
#  62  review_scores_cleanliness                     16035 non-null  float64
#  63  review_scores_checkin                         16021 non-null  float64
#  64  review_scores_communication                   16032 non-null  float64
#  65  review_scores_location                        16023 non-null  float64
#  66  review_scores_value                           16020 non-null  float64
#  67  license                                       2409 non-null   object
#  68  instant_bookable                              20227 non-null  object
#  69  calculated_host_listings_count                20227 non-null  int64
#  70  calculated_host_listings_count_entire_homes   20227 non-null  int64
#  71  calculated_host_listings_count_private_rooms  20227 non-null  int64
#  72  calculated_host_listings_count_shared_rooms   20227 non-null  int64
#  73  reviews_per_month                             16460 non-null  float64
# dtypes: float64(22), int64(17), object(35)
# memory usage: 11.4+ MB

# %% [markdown]
# ## Amenities

# %%
df.amenities.to_frame()
# Out:
#                                                amenities
# 0      ["Long term stays allowed", "Essentials", "Gar...
# 1      ["Wifi", "Iron", "Smoke alarm", "Hangers", "Ki...
# 2      ["Wifi", "Iron", "Smoke alarm", "Hangers", "Ca...
# 3      ["Wifi", "Hangers", "Refrigerator", "Extra pil...
# 4      ["Babysitter recommendations", "Room-darkening...
# ...                                                  ...
# 20222  ["TV", "Iron", "Wifi", "Hangers", "Lock on bed...
# 20223  ["Essentials", "Hangers", "Air conditioning", ...
# 20224  ["Wifi", "Smoke alarm", "Kitchen", "Washer", "...
# 20225  ["Wifi", "Iron", "Smoke alarm", "Hangers", "Ki...
# 20226  ["Long term stays allowed", "Essentials", "Pai...
#
# [20227 rows x 1 columns]

# %%
df['amenities']=df['amenities'].apply(lambda x:len(x.split(','))-1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20227 entries, 0 to 20226
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            20227 non-null  int64
#  1   listing_url                                   20227 non-null  object
#  2   scrape_id                                     20227 non-null  int64
#  3   last_scraped                                  20227 non-null  object
#  4   name                                          20195 non-null  object
#  5   description                                   19709 non-null  object
#  6   neighborhood_overview                         11054 non-null  object
#  7   picture_url                                   20227 non-null  object
#  8   host_id                                       20227 non-null  int64
#  9   host_url                                      20227 non-null  object
#  10  host_name                                     20215 non-null  object
#  11  host_since                                    20215 non-null  object
#  12  host_location                                 20167 non-null  object
#  13  host_about                                    10156 non-null  object
#  14  host_response_time                            10054 non-null  object
#  15  host_response_rate                            10054 non-null  object
#  16  host_acceptance_rate                          13053 non-null  object
#  17  host_is_superhost                             20215 non-null  object
#  18  host_thumbnail_url                            20215 non-null  object
#  19  host_picture_url                              20215 non-null  object
#  20  host_neighbourhood                            14547 non-null  object
#  21  host_listings_count                           20215 non-null  float64
#  22  host_total_listings_count                     20215 non-null  float64
#  23  host_verifications                            20227 non-null  object
#  24  host_has_profile_pic                          20215 non-null  object
#  25  host_identity_verified                        20215 non-null  object
#  26  neighbourhood                                 11055 non-null  object
#  27  neighbourhood_cleansed                        20227 non-null  object
#  28  neighbourhood_group_cleansed                  20227 non-null  object
#  29  latitude                                      20227 non-null  float64
#  30  longitude                                     20227 non-null  float64
#  31  property_type                                 20227 non-null  object
#  32  room_type                                     20227 non-null  object
#  33  accommodates                                  20227 non-null  int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                20205 non-null  object
#  36  bedrooms                                      18542 non-null  float64
#  37  beds                                          19975 non-null  float64
#  38  amenities                                     20227 non-null  int64
#  39  price                                         20227 non-null  object
#  40  minimum_nights                                20227 non-null  int64
#  41  maximum_nights                                20227 non-null  int64
#  42  minimum_minimum_nights                        20224 non-null  float64
#  43  maximum_minimum_nights                        20224 non-null  float64
#  44  minimum_maximum_nights                        20224 non-null  float64
#  45  maximum_maximum_nights                        20224 non-null  float64
#  46  minimum_nights_avg_ntm                        20224 non-null  float64
#  47  maximum_nights_avg_ntm                        20224 non-null  float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              20227 non-null  object
#  50  availability_30                               20227 non-null  int64
#  51  availability_60                               20227 non-null  int64
#  52  availability_90                               20227 non-null  int64
#  53  availability_365                              20227 non-null  int64
#  54  calendar_last_scraped                         20227 non-null  object
#  55  number_of_reviews                             20227 non-null  int64
#  56  number_of_reviews_ltm                         20227 non-null  int64
#  57  number_of_reviews_l30d                        20227 non-null  int64
#  58  first_review                                  16460 non-null  object
#  59  last_review                                   16460 non-null  object
#  60  review_scores_rating                          16053 non-null  float64
#  61  review_scores_accuracy                        16034 non-null  float64
#  62  review_scores_cleanliness                     16035 non-null  float64
#  63  review_scores_checkin                         16021 non-null  float64
#  64  review_scores_communication                   16032 non-null  float64
#  65  review_scores_location                        16023 non-null  float64
#  66  review_scores_value                           16020 non-null  float64
#  67  license                                       2409 non-null   object
#  68  instant_bookable                              20227 non-null  object
#  69  calculated_host_listings_count                20227 non-null  int64
#  70  calculated_host_listings_count_entire_homes   20227 non-null  int64
#  71  calculated_host_listings_count_private_rooms  20227 non-null  int64
#  72  calculated_host_listings_count_shared_rooms   20227 non-null  int64
#  73  reviews_per_month                             16460 non-null  float64
# dtypes: float64(22), int64(18), object(34)
# memory usage: 11.4+ MB

# %% [markdown]
# # Feature Selection

# %%
df1 = df[['price','host_response_rate','availability_365','neighbourhood_group_cleansed','host_is_superhost','property_type',
          'accommodates','room_type','bathrooms_text','bedrooms','beds','minimum_nights',
          'review_scores_rating','amenities','instant_bookable','calculated_host_listings_count']]

# %%
df1
# Out:
#          price host_response_rate  availability_365  \
# 0       $61.14               100%               180
# 1       $90.00                NaN               353
# 2       $28.57               100%               293
# 3       $33.00                NaN                 0
# 4      $180.00                NaN                29
# ...        ...                ...               ...
# 20222   $35.00               100%                 0
# 20223   $37.00               100%                 5
# 20224   $41.00                NaN                 0
# 20225   $89.86               100%               352
# 20226   $86.00                94%               165
#
#       neighbourhood_group_cleansed host_is_superhost  \
# 0                            Mitte                 f
# 1                           Pankow                 f
# 2           Tempelhof - Schöneberg                 f
# 3                           Pankow                 t
# 4                           Pankow                 f
# ...                            ...               ...
# 20222                        Mitte                 f
# 20223                        Mitte                 f
# 20224                        Mitte                 f
# 20225       Tempelhof - Schöneberg                 f
# 20226         Charlottenburg-Wilm.                 f
#
#                    property_type  accommodates        room_type  \
# 0              Entire guesthouse             3  Entire home/apt
# 1               Entire apartment             4  Entire home/apt
# 2      Private room in apartment             1     Private room
# 3      Private room in apartment             2     Private room
# 4               Entire apartment             7  Entire home/apt
# ...                          ...           ...              ...
# 20222  Private room in apartment             2     Private room
# 20223           Entire apartment             2  Entire home/apt
# 20224           Entire apartment             2  Entire home/apt
# 20225           Entire apartment             8  Entire home/apt
# 20226           Entire apartment             9  Entire home/apt
#
#        bathrooms_text  bedrooms  beds  minimum_nights  review_scores_rating  \
# 0              1 bath       1.0   0.0               5                  93.0
# 1              1 bath       1.0   2.0              62                  93.0
# 2       1 shared bath       1.0   1.0               7                  89.0
# 3       1 shared bath       1.0   2.0               1                  97.0
# 4           2.5 baths       4.0   7.0               6                 100.0
# ...               ...       ...   ...             ...                   ...
# 20222  1 private bath       NaN   1.0               1                   NaN
# 20223          1 bath       1.0   1.0              25                   NaN
# 20224          1 bath       NaN   2.0               2                   NaN
# 20225          1 bath       2.0   4.0               1                   NaN
# 20226         2 baths       2.0   9.0               1                  80.0
#
#        amenities instant_bookable  calculated_host_listings_count
# 0             29                f                               6
# 1             13                f                               1
# 2             17                f                               1
# 3             12                t                               1
# 4             32                f                               1
# ...          ...              ...                             ...
# 20222         11                t                               1
# 20223         11                t                               1
# 20224          9                t                               1
# 20225         18                t                               3
# 20226         26                f                               3
#
# [20227 rows x 16 columns]

# %% [markdown]
# # Subseting and Limiting features to support our needs

# %%
df1=df1.loc[(df['accommodates']>=3)&(df1['availability_365']>=30)]
df1
# Out:
#          price host_response_rate  availability_365  \
# 0       $61.14               100%               180
# 1       $90.00                NaN               353
# 6       $90.00                NaN               289
# 8      $159.00               100%               175
# 9       $70.00                NaN               291
# ...        ...                ...               ...
# 20212  $150.00                NaN                90
# 20214   $90.00                NaN               157
# 20215  $158.00               100%               190
# 20225   $89.86               100%               352
# 20226   $86.00                94%               165
#
#       neighbourhood_group_cleansed host_is_superhost  \
# 0                            Mitte                 f
# 1                           Pankow                 f
# 6         Friedrichshain-Kreuzberg                 f
# 8                           Pankow                 t
# 9         Friedrichshain-Kreuzberg                 f
# ...                            ...               ...
# 20212         Charlottenburg-Wilm.                 f
# 20214           Treptow - Köpenick                 f
# 20215       Tempelhof - Schöneberg                 f
# 20225       Tempelhof - Schöneberg                 f
# 20226         Charlottenburg-Wilm.                 f
#
#                    property_type  accommodates        room_type  \
# 0              Entire guesthouse             3  Entire home/apt
# 1               Entire apartment             4  Entire home/apt
# 6               Entire apartment             5  Entire home/apt
# 8                    Entire loft             4  Entire home/apt
# 9               Entire apartment             4  Entire home/apt
# ...                          ...           ...              ...
# 20212  Private room in apartment             5     Private room
# 20214           Entire apartment             6  Entire home/apt
# 20215           Entire apartment             8  Entire home/apt
# 20225           Entire apartment             8  Entire home/apt
# 20226           Entire apartment             9  Entire home/apt
#
#        bathrooms_text  bedrooms  beds  minimum_nights  review_scores_rating  \
# 0              1 bath       1.0   0.0               5                  93.0
# 1              1 bath       1.0   2.0              62                  93.0
# 6              1 bath       1.0   3.0              60                  94.0
# 8              1 bath       2.0   2.0               3                  89.0
# 9              1 bath       1.0   2.0              60                  95.0
# ...               ...       ...   ...             ...                   ...
# 20212  2 shared baths       1.0   6.0               1                   NaN
# 20214       1.5 baths       3.0   5.0               1                 100.0
# 20215         2 baths       4.0   7.0               1                   NaN
# 20225          1 bath       2.0   4.0               1                   NaN
# 20226         2 baths       2.0   9.0               1                  80.0
#
#        amenities instant_bookable  calculated_host_listings_count
# 0             29                f                               6
# 1             13                f                               1
# 6             16                f                               2
# 8             24                f                               1
# 9             14                f                               2
# ...          ...              ...                             ...
# 20212         11                t                               3
# 20214         17                t                               1
# 20215         27                f                              10
# 20225         18                t                               3
# 20226         26                f                               3
#
# [3592 rows x 16 columns]

# %% [markdown]
# ## Renaming Columns
#
# - To visualize it better

# %%
df1.rename(columns = {"neighbourhood_group_cleansed": "neighbourhood_group" },inplace=True)

# %%
df1.isna().sum()
# Out:
# price                               0
# host_response_rate                542
# availability_365                    0
# neighbourhood_group                 0
# host_is_superhost                   0
# property_type                       0
# accommodates                        0
# room_type                           0
# bathrooms_text                      6
# bedrooms                          230
# beds                               28
# minimum_nights                      0
# review_scores_rating              574
# amenities                           0
# instant_bookable                    0
# calculated_host_listings_count      0
# dtype: int64

# %% [markdown]
# # Investigating each columns with NaN, checking missing values and Handling missing Values

# %% [markdown]
# ## Host is Superhost

# %%
df1['host_is_superhost'].unique()
# Out:
# array(['f', 't'], dtype=object)

# %%
df1['host_is_superhost'].value_counts()
# Out:
# f    2659
# t     933
# Name: host_is_superhost, dtype: int64

# %%
df1['host_is_superhost'] = df1['host_is_superhost'].fillna('f')

# %%
df1['host_is_superhost'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## Bathrooms

# %%
df1['bathrooms_text'].unique()
# Out:
# array(['1 bath', '2.5 baths', '1.5 shared baths', '1.5 baths', '2 baths',
#        '1 shared bath', nan, '2 shared baths', '0 baths',
#        '0 shared baths', '1 private bath', '4.5 baths', '3 baths',
#        '4 baths', '4 shared baths', '3 shared baths', 'Half-bath',
#        '3.5 baths', '7 baths', '2.5 shared baths', 'Shared half-bath',
#        '5 shared baths', '8.5 shared baths', '32 baths', '18 baths'],
#       dtype=object)

# %%
df1['bathrooms']=df1['bathrooms_text'].map({'1 bath':1,"2.5 baths":2.5,"0 baths":0,'1.5 baths': 1.5,'2 baths':2,
                                          'Half-bath':0.5,'4 baths':4 ,'nan':0})
df1.drop(columns=['bathrooms_text'],inplace=True)
df1.head(2)
# Out:
#     price host_response_rate  availability_365 neighbourhood_group  \
# 0  $61.14               100%               180               Mitte
# 1  $90.00                NaN               353              Pankow
#
#   host_is_superhost      property_type  accommodates        room_type  \
# 0                 f  Entire guesthouse             3  Entire home/apt
# 1                 f   Entire apartment             4  Entire home/apt
#
#    bedrooms  beds  minimum_nights  review_scores_rating  amenities  \
# 0       1.0   0.0               5                  93.0         29
# 1       1.0   2.0              62                  93.0         13
#
#   instant_bookable  calculated_host_listings_count  bathrooms
# 0                f                               6        1.0
# 1                f                               1        1.0

# %%
df1.isnull().sum()
# Out:
# price                               0
# host_response_rate                542
# availability_365                    0
# neighbourhood_group                 0
# host_is_superhost                   0
# property_type                       0
# accommodates                        0
# room_type                           0
# bedrooms                          230
# beds                               28
# minimum_nights                      0
# review_scores_rating              574
# amenities                           0
# instant_bookable                    0
# calculated_host_listings_count      0
# bathrooms                         576
# dtype: int64

# %%
df1['bathrooms'] = df1['bathrooms'].fillna(value=0)

# %% [markdown]
# ## Price

# %% [markdown]
# ### Removing the '$' sign in price column

# %%
df1['price'] = df1['price'].str.replace('$', '')
df1['price'] = df1['price'].str.replace(',', '')
df1['price'].unique()
# Out:
# array(['61.14', '90.00', '159.00', '70.00', '160.00', '135.00', '65.00',
#        '113.00', '74.00', '35.00', '37.00', '105.00', '81.00', '136.00',
#        '154.00', '51.00', '120.00', '79.00', '60.00', '521.00', '75.00',
#        '119.00', '68.00', '59.00', '55.00', '80.00', '25.00', '161.00',
#        '110.00', '49.00', '78.00', '103.00', '157.00', '170.00', '85.00',
#        '52.00', '89.00', '100.00', '82.00', '84.00', '45.00', '42.00',
#        '190.00', '63.86', '150.00', '93.00', '69.00', '50.00', '98.43',
#        '61.00', '56.00', '30.00', '95.00', '58.00', '17.00', '16.00',
#        '125.00', '240.00', '44.00', '53.00', '47.00', '72.00', '64.00',
#        '32.00', '109.00', '23.00', '130.00', '180.00', '139.00', '140.00',
#        '101.00', '179.00', '245.00', '76.00', '77.00', '40.00', '46.00',
#        '98.00', '106.00', '43.00', '107.00', '63.00', '199.00', '455.00',
#        '42.71', '500.00', '31.00', '141.00', '86.00', '27.00', '57.00',
#        '280.00', '149.00', '83.00', '118.00', '200.00', '87.00', '121.00',
#        '114.00', '97.00', '48.00', '26.00', '126.00', '67.00', '62.00',
#        '360.00', '28.00', '164.00', '183.00', '14.00', '22.00', '88.00',
#        '37.14', '145.00', '162.14', '314.00', '213.00', '203.57',
#        '153.00', '115.00', '390.00', '99.00', '600.00', '94.00', '39.00',
#        '202.00', '129.43', '92.00', '71.00', '165.00', '250.00', '54.00',
#        '450.00', '102.00', '66.00', '189.00', '34.00', '251.43',
#        '2500.00', '29.00', '15.00', '12.00', '67.43', '104.00', '144.00',
#        '400.00', '186.00', '155.00', '36.00', '231.00', '48.77', '290.00',
#        '675.00', '96.00', '208.00', '162.00', '124.00', '20.00', '24.00',
#        '19.00', '116.00', '128.00', '70.71', '41.00', '117.00', '480.00',
#        '158.00', '13.00', '185.00', '210.00', '33.00', '310.00', '270.00',
#        '177.00', '122.00', '403.00', '184.00', '188.00', '220.00',
#        '62.86', '253.00', '249.00', '624.00', '123.00', '166.00',
#        '124.71', '138.00', '164.29', '283.00', '380.00', '137.00',
#        '91.00', '321.00', '18.00', '112.00', '137.14', '369.00', '467.00',
#        '127.00', '899.00', '116.36', '49.15', '48.40', '282.00', '111.00',
#        '236.00', '191.00', '21.00', '194.00', '143.00', '228.00',
#        '108.00', '382.14', '168.00', '285.00', '127.86', '88.86',
#        '108.57', '198.00', '181.00', '300.00', '375.00', '295.00',
#        '38.00', '129.00', '465.00', '279.00', '169.00', '221.00',
#        '203.00', '142.00', '134.00', '204.00', '53.57', '146.00',
#        '229.00', '192.00', '265.00', '193.00', '225.00', '239.00',
#        '1050.00', '35.29', '320.00', '148.00', '87.43', '885.00',
#        '226.00', '175.00', '207.00', '133.00', '385.00', '172.14',
#        '258.00', '193.14', '40.71', '218.00', '72.14', '52.14', '61.43',
#        '73.00', '195.00', '389.00', '114.29', '197.00', '131.00',
#        '173.00', '274.00', '269.00', '86.29', '82.57', '66.54', '650.00',
#        '211.00', '868.00', '350.00', '205.00', '40.14', '318.00',
#        '563.00', '174.00', '101.71', '142.86', '201.00', '216.00',
#        '880.00', '419.66', '46.57', '233.00', '252.00', '230.00',
#        '227.86', '58.57', '368.00', '156.00', '63.57', '171.00', '944.00',
#        '844.00', '94.29', '527.00', '324.00', '101.86', '275.00',
#        '196.00', '694.00', '84.19', '30.57', '126.65', '268.00', '80.57',
#        '296.00', '289.00', '163.00', '525.00', '325.00', '83.79', '11.00',
#        '187.00', '151.00', '456.00', '999.00', '76.69', '160.29',
#        '281.66', '27.86', '172.00', '246.00', '264.00', '223.00',
#        '150.43', '152.00', '420.00', '132.00', '557.00', '362.00',
#        '490.00', '147.00', '99.86', '129.29', '299.00', '55.71', '440.36',
#        '303.00', '99.98', '407.00', '667.00', '179.86', '244.00',
#        '254.00', '178.00', '81.86', '95.26', '36.43', '370.00', '489.00',
#        '449.00', '479.00', '400.43', '119.29', '41.86', '396.00',
#        '990.00', '98.57', '247.00', '263.00', '77.14', '73.50', '151.14',
#        '159.86', '261.00', '242.00', '167.00', '235.00', '237.00',
#        '424.00', '372.00', '131.93', '78.86', '56.71', '59.57', '65.71',
#        '700.00', '1000.00', '750.00', '457.00', '35.71', '214.00',
#        '58.29', '355.00', '106.14', '63.29', '215.00', '89.86'],
#       dtype=object)

# %% [markdown]
# #### Converting Price Column to numeric datatype

# %%
df1['price'] = pd.to_numeric(df1['price'])

# %%
df1.info()
df1.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3592 entries, 0 to 20226
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   price                           3592 non-null   float64
#  1   host_response_rate              3050 non-null   object
#  2   availability_365                3592 non-null   int64
#  3   neighbourhood_group             3592 non-null   object
#  4   host_is_superhost               3592 non-null   object
#  5   property_type                   3592 non-null   object
#  6   accommodates                    3592 non-null   int64
#  7   room_type                       3592 non-null   object
#  8   bedrooms                        3362 non-null   float64
#  9   beds                            3564 non-null   float64
#  10  minimum_nights                  3592 non-null   int64
#  11  review_scores_rating            3018 non-null   float64
#  12  amenities                       3592 non-null   int64
#  13  instant_bookable                3592 non-null   object
#  14  calculated_host_listings_count  3592 non-null   int64
#  15  bathrooms                       3592 non-null   float64
# dtypes: float64(5), int64(5), object(6)
# memory usage: 477.1+ KB
# price                               0
# host_response_rate                542
# availability_365                    0
# neighbourhood_group                 0
# host_is_superhost                   0
# property_type                       0
# accommodates                        0
# room_type                           0
# bedrooms                          230
# beds                               28
# minimum_nights                      0
# review_scores_rating              574
# amenities                           0
# instant_bookable                    0
# calculated_host_listings_count      0
# bathrooms                           0
# dtype: int64

# %% [markdown]
# ## Host response rate

# %%
df1['host_response_rate'].unique()
# Out:
# array(['100%', nan, '86%', '83%', '71%', '67%', '70%', '54%', '72%',
#        '80%', '99%', '0%', '94%', '88%', '75%', '69%', '90%', '50%',
#        '89%', '91%', '93%', '78%', '33%', '40%', '43%', '73%', '97%',
#        '20%', '25%', '57%', '60%', '92%', '30%', '96%', '81%', '76%',
#        '17%', '98%', '87%', '63%', '77%', '82%', '29%', '79%', '56%',
#        '74%', '64%', '6%', '44%', '95%', '85%', '10%', '13%', '59%',
#        '65%', '32%', '14%'], dtype=object)

# %%
df1['host_response_rate'] = df1['host_response_rate'].fillna(value=0)

# %%
df1['host_response_rate'] = df1['host_response_rate'].str.replace('%', '')

# %% [markdown]
# ### Converting host reponse rate column to numeric datatype

# %%
df1['host_response_rate'] = pd.to_numeric(df1['host_response_rate'])

# %% [markdown]
# #### Filling empty values with 0

# %%
df1['host_response_rate']= df1['host_response_rate'].fillna(value=0)

# %%
df1.isna().sum()
# Out:
# price                               0
# host_response_rate                  0
# availability_365                    0
# neighbourhood_group                 0
# host_is_superhost                   0
# property_type                       0
# accommodates                        0
# room_type                           0
# bedrooms                          230
# beds                               28
# minimum_nights                      0
# review_scores_rating              574
# amenities                           0
# instant_bookable                    0
# calculated_host_listings_count      0
# bathrooms                           0
# dtype: int64

# %% [markdown]
# ## Bedrooms

# %%
print(df1['bedrooms'].unique())
df1['bedrooms'] = df1['bedrooms'].fillna(value=1)
# Out:
# [ 1.  2.  3. nan  5.  4.  8.  6. 12.  7. 32. 18.]

# %% [markdown]
# #### Filling empty values in bedrooms column and replacing it with 1, because there is at least 1 bedroom for each accommodation, even whether it is a Motel.

# %%
df1.isna().sum()
# Out:
# price                               0
# host_response_rate                  0
# availability_365                    0
# neighbourhood_group                 0
# host_is_superhost                   0
# property_type                       0
# accommodates                        0
# room_type                           0
# bedrooms                            0
# beds                               28
# minimum_nights                      0
# review_scores_rating              574
# amenities                           0
# instant_bookable                    0
# calculated_host_listings_count      0
# bathrooms                           0
# dtype: int64

# %% [markdown]
# ## Beds

# %%
print(df1['beds'].unique())
df1['beds'] = df1['beds'].fillna(value=0)
# Out:
# [ 0.  2.  3.  4.  1. 10.  6. 15.  5.  8.  7.  9. 16. 12. 11. nan 14. 17.
#  96. 72. 18. 24.]

# %% [markdown]
# #### Filling empty values in beds column and replacing it with 0, asumming guests sleep on a coach or any kind of mattress.

# %%
df1.isna().sum()
# Out:
# price                               0
# host_response_rate                  0
# availability_365                    0
# neighbourhood_group                 0
# host_is_superhost                   0
# property_type                       0
# accommodates                        0
# room_type                           0
# bedrooms                            0
# beds                                0
# minimum_nights                      0
# review_scores_rating              574
# amenities                           0
# instant_bookable                    0
# calculated_host_listings_count      0
# bathrooms                           0
# dtype: int64

# %% [markdown]
# ## Review Scores Rating

# %%
df1['review_scores_rating'].unique()
# Out:
# array([ 93.,  94.,  89.,  95.,  96.,  90.,  98.,  92.,  91.,  81.,  97.,
#         99., 100.,  87.,  88.,  82.,  nan,  80.,  83.,  56.,  76.,  86.,
#         85.,  84.,  53.,  75.,  40.,  78.,  67.,  77.,  72.,  74.,  60.,
#         73.,  79.,  47.,  65.,  70.,  20.,  71.,  64.,  50.,  68.])

# %%
df1['review_scores_rating']= df1['review_scores_rating'].fillna(value=0)

# %%
df1["property_type"] = df1["property_type"].apply(lambda x: "Entire property" if x=='Entire guesthouse' or x=='Entire apartment' or x== 'Entire loft' or x=='Entire guest suite' or x== 'Entire house' or x == 'Entire townhouse' or x=='Entire condominium' or x=='Entire serviced apartment' or x == 'Entire place' or x =='Entire bungalow' or x=='Entire chalet'or x=='Entire floor'or x=='Entire cottage'or x=='Entire cabin'or x=='Entire villa' or x=='Tiny house' else x)
df1["property_type"] = df1["property_type"].apply(lambda x: "Private Room" if x == 'Private room in apartment' or x == 'Private room in loft' or x=='Private room in hostel' or x=='Private room in house' or x== 'Private room' or x== 'Private room in condominium' or x=='Private room in townhouse'or x=='Private room in bed and breakfast' or x=='Private room in houseboat' or x=='Private room in guest suite' or x =='Private room in villa' or x=='Private room in pension' or x=='Private room in serviced apartment' or x=='Private room in barn' or x=='Private room in guesthouse' else x)
df1["property_type"] = df1["property_type"].apply(lambda x: "Shared Room" if x== 'Shared room in hostel'or x=='Shared room in apartment' or x== 'Shared room in loft' or x=='Room in boutique hotel' or x== 'Room in hostel' or x=='Room in aparthotel' or x =='Room in hotel' or x =='Room in bed and breakfast' or x == 'Room in serviced apartment'or x =='Shared room in boutique hotel' or x==  'Shared room in aparthotel' or x== 'Shared room in bed and breakfast' else x)
df1["property_type"] = df1["property_type"].apply(lambda x: "Other" if x== 'Boat'or x=='Houseboat' or x== 'Camper/RV' else x) 
df1["property_type"].unique()
# Out:
# array(['Entire property', 'Private Room', 'Shared Room', 'Other'],
#       dtype=object)

# %%
df1.isna().sum()
# Out:
# price                             0
# host_response_rate                0
# availability_365                  0
# neighbourhood_group               0
# host_is_superhost                 0
# property_type                     0
# accommodates                      0
# room_type                         0
# bedrooms                          0
# beds                              0
# minimum_nights                    0
# review_scores_rating              0
# amenities                         0
# instant_bookable                  0
# calculated_host_listings_count    0
# bathrooms                         0
# dtype: int64

# %%
df1.head()
# Out:
#     price  host_response_rate  availability_365       neighbourhood_group  \
# 0   61.14               100.0               180                     Mitte
# 1   90.00                 0.0               353                    Pankow
# 6   90.00                 0.0               289  Friedrichshain-Kreuzberg
# 8  159.00               100.0               175                    Pankow
# 9   70.00                 0.0               291  Friedrichshain-Kreuzberg
#
#   host_is_superhost    property_type  accommodates        room_type  bedrooms  \
# 0                 f  Entire property             3  Entire home/apt       1.0
# 1                 f  Entire property             4  Entire home/apt       1.0
# 6                 f  Entire property             5  Entire home/apt       1.0
# 8                 t  Entire property             4  Entire home/apt       2.0
# 9                 f  Entire property             4  Entire home/apt       1.0
#
#    beds  minimum_nights  review_scores_rating  amenities instant_bookable  \
# 0   0.0               5                  93.0         29                f
# 1   2.0              62                  93.0         13                f
# 6   3.0              60                  94.0         16                f
# 8   2.0               3                  89.0         24                f
# 9   2.0              60                  95.0         14                f
#
#    calculated_host_listings_count  bathrooms
# 0                               6        1.0
# 1                               1        1.0
# 6                               2        1.0
# 8                               1        1.0
# 9                               2        1.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3592 entries, 0 to 20226
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   price                           3592 non-null   float64
#  1   host_response_rate              3592 non-null   float64
#  2   availability_365                3592 non-null   int64
#  3   neighbourhood_group             3592 non-null   object
#  4   host_is_superhost               3592 non-null   object
#  5   property_type                   3592 non-null   object
#  6   accommodates                    3592 non-null   int64
#  7   room_type                       3592 non-null   object
#  8   bedrooms                        3592 non-null   float64
#  9   beds                            3592 non-null   float64
#  10  minimum_nights                  3592 non-null   int64
#  11  review_scores_rating            3592 non-null   float64
#  12  amenities                       3592 non-null   int64
#  13  instant_bookable                3592 non-null   object
#  14  calculated_host_listings_count  3592 non-null   int64
#  15  bathrooms                       3592 non-null   float64
# dtypes: float64(6), int64(5), object(5)
# memory usage: 477.1+ KB

# %% [markdown]
# # Encoding

# %%
df1['instant_bookable_encode']=df1['instant_bookable'].map({'f':0,'t':1})
df1.drop(columns=['instant_bookable'],inplace=True)
print(df1['instant_bookable_encode'].unique())
# Out:
# [0 1]

# %%
df1['host_is_superhost_encode']=df1['host_is_superhost'].map({'f':0,'t':1})
df1.drop(columns=['host_is_superhost'],inplace=True)
print(df1['host_is_superhost_encode'].unique())
# Out:
# [0 1]

# %%
df1=pd.get_dummies(data=df1,columns=['neighbourhood_group','room_type','property_type'])

df1.head()
# Out:
#     price  host_response_rate  availability_365  accommodates  bedrooms  beds  \
# 0   61.14               100.0               180             3       1.0   0.0
# 1   90.00                 0.0               353             4       1.0   2.0
# 6   90.00                 0.0               289             5       1.0   3.0
# 8  159.00               100.0               175             4       2.0   2.0
# 9   70.00                 0.0               291             4       1.0   2.0
#
#    minimum_nights  review_scores_rating  amenities  \
# 0               5                  93.0         29
# 1              62                  93.0         13
# 6              60                  94.0         16
# 8               3                  89.0         24
# 9              60                  95.0         14
#
#    calculated_host_listings_count  bathrooms  instant_bookable_encode  \
# 0                               6        1.0                        0
# 1                               1        1.0                        0
# 6                               2        1.0                        0
# 8                               1        1.0                        0
# 9                               2        1.0                        0
#
#    host_is_superhost_encode  neighbourhood_group_Charlottenburg-Wilm.  \
# 0                         0                                         0
# 1                         0                                         0
# 6                         0                                         0
# 8                         1                                         0
# 9                         0                                         0
#
#    neighbourhood_group_Friedrichshain-Kreuzberg  \
# 0                                             0
# 1                                             0
# 6                                             1
# 8                                             0
# 9                                             1
#
#    neighbourhood_group_Lichtenberg  neighbourhood_group_Marzahn - Hellersdorf  \
# 0                                0                                          0
# 1                                0                                          0
# 6                                0                                          0
# 8                                0                                          0
# 9                                0                                          0
#
#    neighbourhood_group_Mitte  neighbourhood_group_Neukölln  \
# 0                          1                             0
# 1                          0                             0
# 6                          0                             0
# 8                          0                             0
# 9                          0                             0
#
#    neighbourhood_group_Pankow  neighbourhood_group_Reinickendorf  \
# 0                           0                                  0
# 1                           1                                  0
# 6                           0                                  0
# 8                           1                                  0
# 9                           0                                  0
#
#    neighbourhood_group_Spandau  neighbourhood_group_Steglitz - Zehlendorf  \
# 0                            0                                          0
# 1                            0                                          0
# 6                            0                                          0
# 8                            0                                          0
# 9                            0                                          0
#
#    neighbourhood_group_Tempelhof - Schöneberg  \
# 0                                           0
# 1                                           0
# 6                                           0
# 8                                           0
# 9                                           0
#
#    neighbourhood_group_Treptow - Köpenick  room_type_Entire home/apt  \
# 0                                       0                          1
# 1                                       0                          1
# 6                                       0                          1
# 8                                       0                          1
# 9                                       0                          1
#
#    room_type_Hotel room  room_type_Private room  room_type_Shared room  \
# 0                     0                       0                      0
# 1                     0                       0                      0
# 6                     0                       0                      0
# 8                     0                       0                      0
# 9                     0                       0                      0
#
#    property_type_Entire property  property_type_Other  \
# 0                              1                    0
# 1                              1                    0
# 6                              1                    0
# 8                              1                    0
# 9                              1                    0
#
#    property_type_Private Room  property_type_Shared Room
# 0                           0                          0
# 1                           0                          0
# 6                           0                          0
# 8                           0                          0
# 9                           0                          0

# %%
df1.head()
# Out:
#     price  host_response_rate  availability_365  accommodates  bedrooms  beds  \
# 0   61.14               100.0               180             3       1.0   0.0
# 1   90.00                 0.0               353             4       1.0   2.0
# 6   90.00                 0.0               289             5       1.0   3.0
# 8  159.00               100.0               175             4       2.0   2.0
# 9   70.00                 0.0               291             4       1.0   2.0
#
#    minimum_nights  review_scores_rating  amenities  \
# 0               5                  93.0         29
# 1              62                  93.0         13
# 6              60                  94.0         16
# 8               3                  89.0         24
# 9              60                  95.0         14
#
#    calculated_host_listings_count  bathrooms  instant_bookable_encode  \
# 0                               6        1.0                        0
# 1                               1        1.0                        0
# 6                               2        1.0                        0
# 8                               1        1.0                        0
# 9                               2        1.0                        0
#
#    host_is_superhost_encode  neighbourhood_group_Charlottenburg-Wilm.  \
# 0                         0                                         0
# 1                         0                                         0
# 6                         0                                         0
# 8                         1                                         0
# 9                         0                                         0
#
#    neighbourhood_group_Friedrichshain-Kreuzberg  \
# 0                                             0
# 1                                             0
# 6                                             1
# 8                                             0
# 9                                             1
#
#    neighbourhood_group_Lichtenberg  neighbourhood_group_Marzahn - Hellersdorf  \
# 0                                0                                          0
# 1                                0                                          0
# 6                                0                                          0
# 8                                0                                          0
# 9                                0                                          0
#
#    neighbourhood_group_Mitte  neighbourhood_group_Neukölln  \
# 0                          1                             0
# 1                          0                             0
# 6                          0                             0
# 8                          0                             0
# 9                          0                             0
#
#    neighbourhood_group_Pankow  neighbourhood_group_Reinickendorf  \
# 0                           0                                  0
# 1                           1                                  0
# 6                           0                                  0
# 8                           1                                  0
# 9                           0                                  0
#
#    neighbourhood_group_Spandau  neighbourhood_group_Steglitz - Zehlendorf  \
# 0                            0                                          0
# 1                            0                                          0
# 6                            0                                          0
# 8                            0                                          0
# 9                            0                                          0
#
#    neighbourhood_group_Tempelhof - Schöneberg  \
# 0                                           0
# 1                                           0
# 6                                           0
# 8                                           0
# 9                                           0
#
#    neighbourhood_group_Treptow - Köpenick  room_type_Entire home/apt  \
# 0                                       0                          1
# 1                                       0                          1
# 6                                       0                          1
# 8                                       0                          1
# 9                                       0                          1
#
#    room_type_Hotel room  room_type_Private room  room_type_Shared room  \
# 0                     0                       0                      0
# 1                     0                       0                      0
# 6                     0                       0                      0
# 8                     0                       0                      0
# 9                     0                       0                      0
#
#    property_type_Entire property  property_type_Other  \
# 0                              1                    0
# 1                              1                    0
# 6                              1                    0
# 8                              1                    0
# 9                              1                    0
#
#    property_type_Private Room  property_type_Shared Room
# 0                           0                          0
# 1                           0                          0
# 6                           0                          0
# 8                           0                          0
# 9                           0                          0

# %%
df1.shape
# Out:
# (3592, 33)

# %% [markdown]
# # Splitting Data

# %%
X = df1.drop(columns='price')
y = np.log(df1['price'])

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, random_state=42)

X_train.columns
# Out:
# Index(['host_response_rate', 'availability_365', 'accommodates', 'bedrooms',
#        'beds', 'minimum_nights', 'review_scores_rating', 'amenities',
#        'calculated_host_listings_count', 'bathrooms',
#        'instant_bookable_encode', 'host_is_superhost_encode',
#        'neighbourhood_group_Charlottenburg-Wilm.',
#        'neighbourhood_group_Friedrichshain-Kreuzberg',
#        'neighbourhood_group_Lichtenberg',
#        'neighbourhood_group_Marzahn - Hellersdorf',
#        'neighbourhood_group_Mitte', 'neighbourhood_group_Neukölln',
#        'neighbourhood_group_Pankow', 'neighbourhood_group_Reinickendorf',
#        'neighbourhood_group_Spandau',
#        'neighbourhood_group_Steglitz - Zehlendorf',
#        'neighbourhood_group_Tempelhof - Schöneberg',
#        'neighbourhood_group_Treptow - Köpenick', 'room_type_Entire home/apt',
#        'room_type_Hotel room', 'room_type_Private room',
#        'room_type_Shared room', 'property_type_Entire property',
#        'property_type_Other', 'property_type_Private Room',
#        'property_type_Shared Room'],
#       dtype='object')

# %% [markdown]
# # MODEL BUILDING
#
# ### Random Forest Regressor

# %%
RF = RandomForestRegressor()

RF.fit(X_train, y_train)

y_base_RF = RF.predict(X_test)
RF_pred_train=RF.predict(X_train)

RF_train =  RF.score(X_train,y_train)

r2_model_RF= r2_score(y_test, y_base_RF)
MAE_model_RF = mean_absolute_error(y_test, y_base_RF)
MSE_model_RF= mean_squared_error(y_test, y_base_RF)
RMSE_model_RF= np.sqrt(MSE_model_RF)

print("Evaluation Matrix Random Forest\n")
print("MAE Score: ", MAE_model_RF)
print("MSE Score: ", MSE_model_RF)
print("RMSE Score: ", RMSE_model_RF)
print("R2 : ", r2_model_RF)

print('\ntrain score: ',r2_score(y_train, RF_pred_train))
print('test score: ',r2_score(y_test, y_base_RF))

# Load a regression dataset
train, target = load_concrete()


# Instantiate the linear model and visualizer
visualizer = ResidualsPlot(RF)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
# Out:
# Evaluation Matrix Random Forest
#
# MAE Score:  0.2938952852137841
# MSE Score:  0.16431611384045952
# RMSE Score:  0.4053592404774554
# R2 :  0.5451500333759141
#
# train score:  0.935994493955971
# test score:  0.5451500333759141
# <AxesSubplot:title={'center':'Residuals for RandomForestRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# ## Random Forest Regressor Tuned

# %%
RF_tuning = RandomForestRegressor()
# param_RF = {'max_depth':[3,7,9],
#             'min_samples_split':[2, 5, 9,3],
#             'min_samples_leaf':[1, 5,6,7,8,9,10,100],
#             'max_features':[0.1,0.3,0.9],
#             'n_estimators':[100, 200, 450]}

param_RF = {'max_depth':[3,7,9],
            'min_samples_leaf':[2, 5,9,3],
            'min_samples_split':[1, 5,6,7,8,9,10],
            'max_features':[0.1,0.3,0.9],
            'n_estimators':[100, 200, 450]}

# param_RF = {"n_estimators" : [5,10,20,40,50],
#           "max_depth" : [None, 5, 7, 9, 20, 25],
#           "min_samples_split" : [10, 20, 50, 100],
#           "min_samples_leaf" : [5, 10, 50, 100],
#           "max_features" : [None, .8, .7, .6]} #0.532

#RF_tuned = GridSearchCV(estimator = RF_tuning, param_grid=param_RF, n_jobs = -1, cv=5, verbose =1)
RF_tuned = RandomizedSearchCV(estimator=RF_tuning, param_distributions=param_RF, cv=20, n_iter=100, n_jobs=-1, verbose=1)
RF_tuned.fit(X_train, y_train)

RF_tuned_train = RF_tuned.best_score_
RF_model_tuned = RF_tuned.best_estimator_

y_RF_tuned =  RF_model_tuned.predict(X_test)
RF_tuned_train =  RF_model_tuned.predict(X_train)


r2_tuned_RF = r2_score(y_test, y_RF_tuned)
MAE_RF_tuned = mean_absolute_error(y_test, y_RF_tuned)
MSE_RF_tuned = mean_squared_error(y_test, y_RF_tuned)
RMSE_RF_tuned = np.sqrt(MSE_RF_tuned)

print("Evaluation Matrix Random Forest Tuned\n")
print("MAE Score: ", MAE_RF_tuned)
print("MSE Score: ", MSE_RF_tuned)
print("RMSE Score: ", RMSE_RF_tuned)
print("R2 : ", r2_tuned_RF)

print('\ntrain score: ',r2_score(y_train, RF_tuned_train))
print('test score: ',r2_score(y_test, y_RF_tuned))

# Load a regression dataset
train, target = load_concrete()


# Instantiate the linear model and visualizer
visualizer = ResidualsPlot(RF_tuned)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
# Out:
# Fitting 20 folds for each of 100 candidates, totalling 2000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 19.3min
# [Parallel(n_jobs=-1)]: Done 2000 out of 2000 | elapsed: 21.4min finished
# Evaluation Matrix Random Forest Tuned
#
# MAE Score:  0.30546857220032037
# MSE Score:  0.1634884118637744
# RMSE Score:  0.40433700283770024
# R2 :  0.5474412281204262
#
# train score:  0.6821707542630686
# test score:  0.5474412281204262
# <AxesSubplot:title={'center':'Residuals for RandomizedSearchCV Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# ## Ridge

# %%
from sklearn.linear_model import Ridge

Ridge = Ridge(alpha=7)

Ridge.fit(X_train, y_train)

y_model_Ridge = Ridge.predict(X_test)
Ridge_pred_train=Ridge.predict(X_train)

Ridge_train =  Ridge.score(X_train,y_train)

r2_model_Ridge= (r2_score(y_test, y_model_Ridge))
MAE_model_Ridge = mean_absolute_error(y_test, y_model_Ridge)
MSE_model_Ridge= mean_squared_error(y_test, y_model_Ridge)
RMSE_model_Ridge= np.sqrt(MSE_model_Ridge)

print("Evaluation Matrix Ridge\n")
print("MAE Score: ", MAE_model_Ridge)
print("MSE Score: ", MSE_model_Ridge)
print("RMSE Score: ", RMSE_model_Ridge)
print("R2 : ", r2_model_Ridge)

print('\ntrain score: ',r2_score(y_train, Ridge_pred_train))
print('test score: ',r2_score(y_test, y_model_Ridge))

# Load a regression dataset
train, target = load_concrete()


# Instantiate the linear model and visualizer
visualizer = ResidualsPlot(Ridge)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
# Out:
# Evaluation Matrix Ridge
#
# MAE Score:  0.3413031750355062
# MSE Score:  0.19479625267496437
# RMSE Score:  0.44135728460620693
# R2 :  0.46077674942013
#
# train score:  0.4743940298145708
# test score:  0.46077674942013
# <AxesSubplot:title={'center':'Residuals for Ridge Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# ## Ridge Tuned

# %%
from sklearn.linear_model import Ridge

ridge_tuning = Ridge()
param_ridge = {'alpha':[1,5,9,13, 17, 300, 6000],
               'fit_intercept':[True, False],
              'normalize': [False, True],
              'copy_X':[True, False],
              'max_iter':[None, 10, 100, 1000,10000],
              'tol':[0.001, 0.005, 0.01]}

model_ridge_tuned = GridSearchCV(estimator = ridge_tuning, param_grid=param_ridge, n_jobs = -1, cv=5, verbose =1)
model_ridge_tuned.fit(X_train, y_train)

ridge_tuned_train = model_ridge_tuned.best_score_
ridge_tuned = model_ridge_tuned.best_estimator_

y_ridge_tuned =  ridge_tuned.predict(X_test)
Ridge_tuned_train = ridge_tuned.predict(X_train)

r2_tuned_ridge = r2_score(y_test, y_ridge_tuned)
MAE_ridge_tuned = mean_absolute_error(y_test, y_ridge_tuned)
MSE_ridge_tuned = mean_squared_error(y_test, y_ridge_tuned)
RMSE_ridge_tuned = np.sqrt(MSE_ridge_tuned)

print("Evaluation Matrix Ridge Tuned\n")
print("MAE Score: ", MAE_ridge_tuned)
print("MSE Score: ", MSE_ridge_tuned)
print("RMSE Score: ", RMSE_ridge_tuned)
print("R2 : ", r2_tuned_ridge)

print('\ntrain score: ',r2_score(y_train, Ridge_tuned_train))
print('test score: ',r2_score(y_test, y_ridge_tuned))

# Load a regression dataset
train, target = load_concrete()


# Instantiate the linear model and visualizer
visualizer = ResidualsPlot(model_ridge_tuned)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
# Out:
# Fitting 5 folds for each of 840 candidates, totalling 4200 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 200 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 1400 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 3400 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=-1)]: Done 4200 out of 4200 | elapsed:   36.0s finished
# Evaluation Matrix Ridge Tuned
#
# MAE Score:  0.34043204634918084
# MSE Score:  0.1941729022066331
# RMSE Score:  0.44065054431673306
# R2 :  0.4625022706309765
#
# train score:  0.47720004468710797
# test score:  0.4625022706309765
# <AxesSubplot:title={'center':'Residuals for GridSearchCV Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# ## XG Boost

# %%
base_XGB = XGBRegressor()

base_XGB.fit(X_train, y_train)

y_base_XGB = base_XGB.predict(X_test)
XGB_pred_train=base_XGB.predict(X_train)

r2_base_XGB = r2_score(y_test, y_base_XGB)

r2_model_XGB= (r2_score(y_test, y_base_XGB))
MAE_model_XGB = mean_absolute_error(y_test, y_base_XGB)
MSE_model_XGB= mean_squared_error(y_test, y_base_XGB)
RMSE_model_XGB= np.sqrt(MSE_model_XGB)

print("Evaluation Matrix XG-Boost\n")
print("MAE Score: ", MAE_model_XGB)
print("MSE Score: ", MSE_model_XGB)
print("RMSE Score: ", RMSE_model_XGB)
print("R2 : ", r2_model_XGB)

print('\ntrain score: ',r2_score(y_train, XGB_pred_train))
print('test score: ',r2_score(y_test, y_base_XGB))

# Load a regression dataset
train, target = load_concrete()


# Instantiate the linear model and visualizer
visualizer = ResidualsPlot(base_XGB)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
# Out:
# Evaluation Matrix XG-Boost
#
# MAE Score:  0.3092699642936205
# MSE Score:  0.17057467737273016
# RMSE Score:  0.4130068732754095
# R2 :  0.5278254548715077
#
# train score:  0.9507076296457418
# test score:  0.5278254548715077
# <AxesSubplot:title={'center':'Residuals for XGBRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# ## XG Boost Tuned

# %%
XGB_tuned =XGBRegressor()
param_XGB_tuned = {'max_depth': [120,150,200],
                 'learning_rate': [0.1, 0.3, 0.5, 1,2],
                 'n_estimator': [100],
                 'gamma': [0, 0.3, 0.5,0.7,1,2],
                 'colsample_bytree': [1, 1.4, 0.5],
                 'subsample':[1,5,7,20,70,90,100],
                 'reg_alpha':[0, 0.5, 1.0,2,7,10],
                 'reg_lambda':[1, 3,7]}

model_XGB_tuned = RandomizedSearchCV(estimator=XGB_tuned, param_distributions=param_XGB_tuned, cv=2, n_iter=20, n_jobs=-1, verbose=1)


model_XGB_tuned.fit(X_train, y_train)

XGB_tuned_train = model_XGB_tuned.best_score_
XGB_tuned = model_XGB_tuned.best_estimator_

y_XGB_tuned =  XGB_tuned.predict(X_test)
XGB_tuned_train = XGB_tuned.predict(X_train)

r2_tuned_XGB = r2_score(y_test, y_XGB_tuned)
MAE_XGB_tuned = mean_absolute_error(y_test, y_XGB_tuned)
MSE_XGB_tuned = mean_squared_error(y_test, y_XGB_tuned)
RMSE_XGB_tuned = np.sqrt(MSE_XGB_tuned)

print("Evaluation Matrix XG Boost Tuned\n")
print("MAE Score: ", MAE_XGB_tuned)
print("MSE Score: ", MSE_XGB_tuned)
print("RMSE Score: ", RMSE_XGB_tuned)
print("R2 : ", r2_tuned_XGB)

print('\ntrain score: ',r2_score(y_train, XGB_tuned_train))
print('test score: ',r2_score(y_test, y_XGB_tuned))

# Load a regression dataset
train, target = load_concrete()


# Instantiate the linear model and visualizer
visualizer = ResidualsPlot(XGB_tuned)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
# Out:
# Fitting 2 folds for each of 20 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:    4.0s finished
# [16:37:40] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { n_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Evaluation Matrix XG Boost Tuned
#
# MAE Score:  0.3084490576143254
# MSE Score:  0.16047230554895348
# RMSE Score:  0.40058994688952626
# R2 :  0.5557902319068899
#
# train score:  0.6104076992615233
# test score:  0.5557902319068899
# <AxesSubplot:title={'center':'Residuals for XGBRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
data = {
    "Random Forest" : [(r2_score(y_train, RF_pred_train)),(r2_score(y_test, y_base_RF))],
    "Random Forest Tuned" : [(r2_score(y_train, RF_tuned_train)),(r2_score(y_test, y_RF_tuned))],
    "Ridge" : [(r2_score(y_train, Ridge_pred_train)),(r2_score(y_test, y_model_Ridge))],
    "Ridge Tuned" : [r2_score(y_train, Ridge_tuned_train), (r2_score(y_test, y_ridge_tuned))],
    "XG Boost "  : [(r2_score(y_train, XGB_pred_train)),(r2_score(y_test, y_base_XGB))],
    "XG Boost Tuned" : [r2_score(y_train, XGB_tuned_train),r2_score(y_test, y_XGB_tuned)],
}
pd.DataFrame(data=data, index=['R2 Score Training', 'R2 Score Testing'])
# Out:
#                    Random Forest  Random Forest Tuned     Ridge  Ridge Tuned  \
# R2 Score Training       0.935994             0.682171  0.474394     0.477200
# R2 Score Testing        0.545150             0.547441  0.460777     0.462502
#
#                    XG Boost   XG Boost Tuned
# R2 Score Training   0.950708        0.610408
# R2 Score Testing    0.527825        0.555790

# %%
# Summary

# %%
# Recommendation

# %% [markdown]
# # Export Model

# %%
import joblib

# %%
joblib.dump(model_XGB_tuned,'XGB_tuned_model')
# Out:
# ['XGB_tuned_model']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3592 entries, 0 to 20226
# Data columns (total 33 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   price                                         3592 non-null   float64
#  1   host_response_rate                            3592 non-null   float64
#  2   availability_365                              3592 non-null   int64
#  3   accommodates                                  3592 non-null   int64
#  4   bedrooms                                      3592 non-null   float64
#  5   beds                                          3592 non-null   float64
#  6   minimum_nights                                3592 non-null   int64
#  7   review_scores_rating                          3592 non-null   float64
#  8   amenities                                     3592 non-null   int64
#  9   calculated_host_listings_count                3592 non-null   int64
#  10  bathrooms                                     3592 non-null   float64
#  11  instant_bookable_encode                       3592 non-null   int64
#  12  host_is_superhost_encode                      3592 non-null   int64
#  13  neighbourhood_group_Charlottenburg-Wilm.      3592 non-null   uint8
#  14  neighbourhood_group_Friedrichshain-Kreuzberg  3592 non-null   uint8
#  15  neighbourhood_group_Lichtenberg               3592 non-null   uint8
#  16  neighbourhood_group_Marzahn - Hellersdorf     3592 non-null   uint8
#  17  neighbourhood_group_Mitte                     3592 non-null   uint8
#  18  neighbourhood_group_Neukölln                  3592 non-null   uint8
#  19  neighbourhood_group_Pankow                    3592 non-null   uint8
#  20  neighbourhood_group_Reinickendorf             3592 non-null   uint8
#  21  neighbourhood_group_Spandau                   3592 non-null   uint8
#  22  neighbourhood_group_Steglitz - Zehlendorf     3592 non-null   uint8
#  23  neighbourhood_group_Tempelhof - Schöneberg    3592 non-null   uint8
#  24  neighbourhood_group_Treptow - Köpenick        3592 non-null   uint8
#  25  room_type_Entire home/apt                     3592 non-null   uint8
#  26  room_type_Hotel room                          3592 non-null   uint8
#  27  room_type_Private room                        3592 non-null   uint8
#  28  room_type_Shared room                         3592 non-null   uint8
#  29  property_type_Entire property                 3592 non-null   uint8
#  30  property_type_Other                           3592 non-null   uint8
#  31  property_type_Private Room                    3592 non-null   uint8
#  32  property_type_Shared Room                     3592 non-null   uint8
# dtypes: float64(6), int64(7), uint8(20)
# memory usage: 463.0 KB

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2873 entries, 6732 to 18610
# Data columns (total 32 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host_response_rate                            2873 non-null   float64
#  1   availability_365                              2873 non-null   int64
#  2   accommodates                                  2873 non-null   int64
#  3   bedrooms                                      2873 non-null   float64
#  4   beds                                          2873 non-null   float64
#  5   minimum_nights                                2873 non-null   int64
#  6   review_scores_rating                          2873 non-null   float64
#  7   amenities                                     2873 non-null   int64
#  8   calculated_host_listings_count                2873 non-null   int64
#  9   bathrooms                                     2873 non-null   float64
#  10  instant_bookable_encode                       2873 non-null   int64
#  11  host_is_superhost_encode                      2873 non-null   int64
#  12  neighbourhood_group_Charlottenburg-Wilm.      2873 non-null   uint8
#  13  neighbourhood_group_Friedrichshain-Kreuzberg  2873 non-null   uint8
#  14  neighbourhood_group_Lichtenberg               2873 non-null   uint8
#  15  neighbourhood_group_Marzahn - Hellersdorf     2873 non-null   uint8
#  16  neighbourhood_group_Mitte                     2873 non-null   uint8
#  17  neighbourhood_group_Neukölln                  2873 non-null   uint8
#  18  neighbourhood_group_Pankow                    2873 non-null   uint8
#  19  neighbourhood_group_Reinickendorf             2873 non-null   uint8
#  20  neighbourhood_group_Spandau                   2873 non-null   uint8
#  21  neighbourhood_group_Steglitz - Zehlendorf     2873 non-null   uint8
#  22  neighbourhood_group_Tempelhof - Schöneberg    2873 non-null   uint8
#  23  neighbourhood_group_Treptow - Köpenick        2873 non-null   uint8
#  24  room_type_Entire home/apt                     2873 non-null   uint8
#  25  room_type_Hotel room                          2873 non-null   uint8
#  26  room_type_Private room                        2873 non-null   uint8
#  27  room_type_Shared room                         2873 non-null   uint8
#  28  property_type_Entire property                 2873 non-null   uint8
#  29  property_type_Other                           2873 non-null   uint8
#  30  property_type_Private Room                    2873 non-null   uint8
#  31  property_type_Shared Room                     2873 non-null   uint8
# dtypes: float64(5), int64(7), uint8(20)
# memory usage: 347.9 KB

# %%
df1[df1['neighbourhood_group_Marzahn - Hellersdorf']==1].head()
# Out:
#       price  host_response_rate  availability_365  accommodates  bedrooms  \
# 720    30.0               100.0               231             3       1.0
# 1894  120.0               100.0               343             6       2.0
# 2927   50.0               100.0                48             3       1.0
# 3379   33.0                 0.0               363             3       1.0
# 3833   69.0               100.0               351             6       3.0
#
#       beds  minimum_nights  review_scores_rating  amenities  \
# 720    3.0               1                  99.0         33
# 1894   6.0               3                 100.0         40
# 2927   2.0               2                  97.0         30
# 3379   2.0              62                 100.0         16
# 3833   3.0               3                  97.0         33
#
#       calculated_host_listings_count  bathrooms  instant_bookable_encode  \
# 720                                1        0.0                        1
# 1894                               1        1.0                        0
# 2927                               1        1.0                        0
# 3379                               1        1.0                        0
# 3833                               1        1.0                        0
#
#       host_is_superhost_encode  neighbourhood_group_Charlottenburg-Wilm.  \
# 720                          1                                         0
# 1894                         0                                         0
# 2927                         1                                         0
# 3379                         0                                         0
# 3833                         1                                         0
#
#       neighbourhood_group_Friedrichshain-Kreuzberg  \
# 720                                              0
# 1894                                             0
# 2927                                             0
# 3379                                             0
# 3833                                             0
#
#       neighbourhood_group_Lichtenberg  \
# 720                                 0
# 1894                                0
# 2927                                0
# 3379                                0
# 3833                                0
#
#       neighbourhood_group_Marzahn - Hellersdorf  neighbourhood_group_Mitte  \
# 720                                           1                          0
# 1894                                          1                          0
# 2927                                          1                          0
# 3379                                          1                          0
# 3833                                          1                          0
#
#       neighbourhood_group_Neukölln  neighbourhood_group_Pankow  \
# 720                              0                           0
# 1894                             0                           0
# 2927                             0                           0
# 3379                             0                           0
# 3833                             0                           0
#
#       neighbourhood_group_Reinickendorf  neighbourhood_group_Spandau  \
# 720                                   0                            0
# 1894                                  0                            0
# 2927                                  0                            0
# 3379                                  0                            0
# 3833                                  0                            0
#
#       neighbourhood_group_Steglitz - Zehlendorf  \
# 720                                           0
# 1894                                          0
# 2927                                          0
# 3379                                          0
# 3833                                          0
#
#       neighbourhood_group_Tempelhof - Schöneberg  \
# 720                                            0
# 1894                                           0
# 2927                                           0
# 3379                                           0
# 3833                                           0
#
#       neighbourhood_group_Treptow - Köpenick  room_type_Entire home/apt  \
# 720                                        0                          0
# 1894                                       0                          1
# 2927                                       0                          1
# 3379                                       0                          1
# 3833                                       0                          1
#
#       room_type_Hotel room  room_type_Private room  room_type_Shared room  \
# 720                      0                       1                      0
# 1894                     0                       0                      0
# 2927                     0                       0                      0
# 3379                     0                       0                      0
# 3833                     0                       0                      0
#
#       property_type_Entire property  property_type_Other  \
# 720                               0                    0
# 1894                              1                    0
# 2927                              1                    0
# 3379                              1                    0
# 3833                              1                    0
#
#       property_type_Private Room  property_type_Shared Room
# 720                            1                          0
# 1894                           0                          0
# 2927                           0                          0
# 3379                           0                          0
# 3833                           0                          0

# %%
df['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room', 'Hotel room'],
#       dtype=object)
